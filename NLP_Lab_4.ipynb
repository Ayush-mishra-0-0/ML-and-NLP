# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush-mishra-0-0/ML/blob/main/NLP_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
# # DSL-504 NLP
#
# ## LAB Assignment - 4
#
# ### 06/10/2024
#
# </div>
#
# ---
#
# <div align="center">
#
# **Name:** Ayush Kumar Mishra
# **Roll No:** 12240340
#
# </div>

# %% [markdown]
# #**Q1**
#
# ###Train an RNN and an LSTM model for two different tasks:
#
# ###Task 1: Language Modeling
#
# ###Task 2: Sentiment Analysis
#
# ###Compare the performance of RNN and LSTM models for each task using suitable evaluation metrics.
#
# ###For example, compare the perplexity values in case of language modeling; and accuracy, F1 score for sentiment analysis

# %% [markdown]
# # Training RNN and LSTM Models for Language Tasks
#
# ## Overview
#
# This guide outlines the process of training two types of neural network models, RNN and LSTM, for the tasks of Language Modeling and Sentiment Analysis. Language modeling involves predicting the next word in a sequence, while sentiment analysis aims to classify text based on emotional tone.
#
# ### Task 1: Language Modeling
#
# 1. **Data Preparation**:
#    - The Penn Tree Bank (PTB) dataset is utilized for training the language model.
#    - This dataset consists of sequences of words, making it suitable for training language models.
#
# 2. **Model Definition**:
#    - An RNN model (`RNNForLM`) is defined with parameters like vocabulary size and number of LSTM units.
#    - The model is wrapped in a Chainer classifier for easier training and evaluation.
#
# 3. **Optimizer Setup**:
#    - An optimizer (e.g., Adam) is initialized and associated with the model. The optimizer is responsible for updating the model parameters during training.
#
# 4. **Training Loop**:
#    - A `BPTTUpdater` (Backpropagation Through Time Updater) is created to handle the training iterations.
#    - A `Trainer` is established to manage the overall training process.
#    - Evaluation during training is facilitated by the `Evaluator` extension, which resets the model's state at the beginning of each evaluation.
#
# 5. **Logging and Monitoring**:
#    - Training logs are generated at regular intervals to monitor the perplexity of the model during training and validation.

# %%
# !pip install chainer
# Out:
# Collecting chainer
#   Downloading chainer-7.8.1.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from chainer) (71.0.4)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from chainer) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from chainer) (3.16.1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from chainer) (1.26.4)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from chainer) (3.20.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from chainer) (1.16.0)
# Building wheels for collected packages: chainer
#   Building wheel for chainer (setup.py) ... done
#   Created wheel for chainer: filename=chainer-7.8.1-py3-none-any.whl size=971816 sha256=cabfdb3316b390986f873fb942acf04a78e2c3ade28fa468003cc413b178b6be
#   Stored in directory: /root/.cache/pip/wheels/c4/95/6a/16014db6f761c4e742755b64aac60dbe142da1df6c5919f790
# Successfully built chainer
# Installing collected packages: chainer
# Successfully installed chainer-7.8.1

# %%
from __future__ import division
import argparse
import sys
import chainer
import chainer.links as L
import chainer.functions as F
import numpy as np
parser = argparse.ArgumentParser(description='Argument parser for training script')

# %%
class RNNForLM(chainer.Chain):

    def __init__(self, n_vocab, n_units):
        super(RNNForLM, self).__init__()
        with self.init_scope():
            self.embed = L.EmbedID(n_vocab, n_units)
            self.l1 = L.LSTM(n_units, n_units)
            self.l2 = L.LSTM(n_units, n_units)
            self.l3 = L.Linear(n_units, n_vocab)

        for param in self.params():
            param.array[...] = np.random.uniform(-0.1, 0.1, param.shape)

    def reset_state(self):
        self.l1.reset_state()
        self.l2.reset_state()

    def forward(self, x):
        h0 = self.embed(x)
        h1 = self.l1(F.dropout(h0))
        h2 = self.l2(F.dropout(h1))
        y = self.l3(F.dropout(h2))
        return y

# %%
# Load the Penn Tree Bank long word sequence dataset
train, val, test = chainer.datasets.get_ptb_words()
# Out:
# Downloading from https://raw.githubusercontent.com/wojzaremba/lstm/master/data/ptb.train.txt...
# Downloading from https://raw.githubusercontent.com/wojzaremba/lstm/master/data/ptb.valid.txt...
# Downloading from https://raw.githubusercontent.com/wojzaremba/lstm/master/data/ptb.test.txt...

# %%
class ParallelSequentialIterator(chainer.dataset.Iterator):

    def __init__(self, dataset, batch_size, repeat=True):
        super(ParallelSequentialIterator, self).__init__()
        self.dataset = dataset
        self.batch_size = batch_size  # batch size
        self.repeat = repeat
        length = len(dataset)
        # Offsets maintain the position of each sequence in the mini-batch.
        self.offsets = [i * length // batch_size for i in range(batch_size)]
        self.reset()

    def reset(self):
        # Number of completed sweeps over the dataset. In this case, it is
        # incremented if every word is visited at least once after the last
        # increment.
        self.epoch = 0
        # True if the epoch is incremented at the last iteration.
        self.is_new_epoch = False
        # NOTE: this is not a count of parameter updates. It is just a count of
        # calls of ``__next__``.
        self.iteration = 0
        # use -1 instead of None internally
        self._previous_epoch_detail = -1.

    def __next__(self):
        # This iterator returns a list representing a mini-batch. Each item
        # indicates a different position in the original sequence. Each item is
        # represented by a pair of two word IDs. The first word is at the
        # "current" position, while the second word at the next position.
        # At each iteration, the iteration count is incremented, which pushes
        # forward the "current" position.
        length = len(self.dataset)
        if not self.repeat and self.iteration * self.batch_size >= length:
            # If not self.repeat, this iterator stops at the end of the first
            # epoch (i.e., when all words are visited once).
            raise StopIteration
        cur_words = self.get_words()
        self._previous_epoch_detail = self.epoch_detail
        self.iteration += 1
        next_words = self.get_words()

        epoch = self.iteration * self.batch_size // length
        self.is_new_epoch = self.epoch < epoch
        if self.is_new_epoch:
            self.epoch = epoch

        return list(zip(cur_words, next_words))

    @property
    def epoch_detail(self):
        # Floating point version of epoch.
        return self.iteration * self.batch_size / len(self.dataset)

    @property
    def previous_epoch_detail(self):
        if self._previous_epoch_detail < 0:
            return None
        return self._previous_epoch_detail

    def get_words(self):
        # It returns a list of current words.
        return [self.dataset[(offset + self.iteration) % len(self.dataset)]
                for offset in self.offsets]

    def serialize(self, serializer):
        # It is important to serialize the state to be recovered on resume.
        self.iteration = serializer('iteration', self.iteration)
        self.epoch = serializer('epoch', self.epoch)
        try:
            self._previous_epoch_detail = serializer(
                'previous_epoch_detail', self._previous_epoch_detail)
        except KeyError:
            # guess previous_epoch_detail for older version
            self._previous_epoch_detail = self.epoch + \
                (self.current_position - self.batch_size) / len(self.dataset)
            if self.epoch_detail > 0:
                self._previous_epoch_detail = max(
                    self._previous_epoch_detail, 0.)
            else:
                self._previous_epoch_detail = -1.

# %% [markdown]
# $$
# \mathcal{L} = - \sum_{t=0}^T \sum_{n=1}^{|\mathcal{V}|}
# \hat{P}(\mathbf{x}_{t+1}^{(n)})
# \log P_{\text{model}}(\mathbf{x}_{t+1}^{(n)} \mid \mathbf{x}_t^{(n)})
# $$

# %%
from chainer import training
class BPTTUpdater(training.updaters.StandardUpdater):

    def __init__(self, train_iter, optimizer, bprop_len, device):
        super(BPTTUpdater, self).__init__(
            train_iter, optimizer, device=device)
        self.bprop_len = bprop_len

    # The core part of the update routine can be customized by overriding.
    def update_core(self):
        loss = 0
        # When we pass one iterator and optimizer to StandardUpdater.__init__,
        # they are automatically named 'main'.
        train_iter = self.get_iterator('main')
        optimizer = self.get_optimizer('main')

        # Progress the dataset iterator for bprop_len words at each iteration.
        for i in range(self.bprop_len):
            # Get the next batch (a list of tuples of two word IDs)
            batch = train_iter.__next__()

            # Concatenate the word IDs to matrices and send them to the device
            # self.converter does this job
            # (it is chainer.dataset.concat_examples by default)
            x, t = self.converter(batch, self.device)

            # Compute the loss at this time step and accumulate it
            loss += optimizer.target(x, t)

        optimizer.target.cleargrads()  # Clear the parameter gradients
        loss.backward()  # Backprop
        loss.unchain_backward()  # Truncate the graph
        optimizer.update()  # Update the parameters

# %%
def compute_perplexity(result):
    result['perplexity'] = np.exp(result['main/loss'])
    if 'validation/main/loss' in result:
        result['val_perplexity'] = np.exp(result['validation/main/loss'])

# %%
args = parser.parse_args(args=[])

# %%
# !pip install --upgrade chainer
# Out:
# Requirement already satisfied: chainer in /usr/local/lib/python3.10/dist-packages (7.8.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from chainer) (71.0.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from chainer) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from chainer) (3.16.1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from chainer) (1.26.4)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from chainer) (3.20.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from chainer) (1.16.0)

# %%
import argparse

# Argument parser setup
parser = argparse.ArgumentParser(description='Argument parser for training script')
parser.add_argument('--batchsize', '-b', type=int, default=16, help='Number of examples in each mini-batch')
parser.add_argument('--bproplen', '-l', type=int, default=35, help='Number of words in each mini-batch')
parser.add_argument('--epoch', '-e', type=int, default=2, help='Number of sweeps over the dataset to train')
parser.add_argument('--device', '-d', type=str, default='-1', help='Device specifier')
parser.add_argument('--gradclip', '-c', type=float, default=5, help='Gradient norm threshold to clip')
parser.add_argument('--out', '-o', default='result', help='Directory to output the result')
parser.add_argument('--resume', '-r', type=str, help='Resume the training from snapshot')
parser.add_argument('--test', action='store_true', help='Use tiny datasets for quick tests')
parser.set_defaults(test=False)
parser.add_argument('--unit', '-u', type=int, default=650, help='Number of LSTM units in each layer')
parser.add_argument('--model', '-m', default='model.npz', help='Model file name to serialize')

# Parse arguments, ensuring compatibility with Jupyter/Colab
try:
    args = parser.parse_args(args=[])  # In Jupyter, use an empty list of args
except:
    args = parser.parse_args()  # Standard behavior outside of Jupyter

# Assuming you have `train`, `val`, and `test` datasets already prepared
train_iter = ParallelSequentialIterator(train, args.batchsize)
val_iter = ParallelSequentialIterator(val, 1, repeat=False)
test_iter = ParallelSequentialIterator(test, 1, repeat=False)

# %%
n_vocab = max(max(train), max(val), max(test)) + 1

# %%
rnn = RNNForLM(n_vocab, args.unit)
model = L.Classifier(rnn)
model.compute_accuracy = False  # we only want the perplexity

# %%
optimizer = chainer.optimizers.SGD(lr=1.0)
optimizer.setup(model)
optimizer.add_hook(chainer.optimizer_hooks.GradientClipping(args.gradclip))

# %%
device = int(args.device) if args.device != '-1' else -1

# %%
import cupy

# Check for CUDA availability and version
if cupy.cuda.is_available():
    cuda_version = cupy.cuda.runtime.runtimeGetVersion()
    print(f"CUDA is available. Version: {cuda_version}")
    device = 0  # Use the first GPU
else:
    print("CUDA is not available, using CPU.")
    device = -1  # Use CPU
# Out:
# CUDA is available. Version: 12020

# %%
from chainer import training, optimizers

# %%
# Define your model and optimizer
rnn = RNNForLM(n_vocab, args.unit).to_device(device)  # Move model to GPU
model = L.Classifier(rnn).to_device(device)  # Move classifier to GPU
optimizer = optimizers.Adam().setup(model)

# Create the updater and trainer
updater = BPTTUpdater(train_iter, optimizer, args.bproplen, device)
trainer = training.Trainer(updater, (args.epoch, 'epoch'), out=args.out)

# Evaluator setup
eval_model = model.copy()  # Model with shared params and distinct states
eval_rnn = eval_model.predictor

trainer.extend(extensions.Evaluator(
    val_iter, eval_model, device=device,
    eval_hook=lambda _: eval_rnn.reset_state()
))

# Logging and snapshots
interval = 10 if args.test else 500
trainer.extend(extensions.LogReport(postprocess=compute_perplexity,
                                     trigger=(interval, 'iteration')))
trainer.extend(extensions.PrintReport(
    ['epoch', 'iteration', 'perplexity', 'val_perplexity']
), trigger=(interval, 'iteration'))
trainer.extend(extensions.ProgressBar(
    update_interval=1 if args.test else 10))
trainer.extend(extensions.snapshot())
trainer.extend(extensions.snapshot_object(
    model, 'model_iter_{.updater.iteration}'))

if args.resume is not None:
    chainer.serializers.load_npz(args.resume, trainer)

# Start the training process
trainer.run()
# Out:
#      total [..................................................]  1.02%
# this epoch [#.................................................]  2.05%
#         10 iter, 0 epoch / 2 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.33%
# this epoch [#.................................................]  2.65%
#         20 iter, 0 epoch / 2 epochs
#     3.3041 iters/sec. Estimated time to finish: 0:16:31.473099.
#      total [..................................................]  1.63%
# this epoch [#.................................................]  3.25%
#         30 iter, 0 epoch / 2 epochs
#     3.6177 iters/sec. Estimated time to finish: 0:15:02.776929.
#      total [..................................................]  1.93%
# this epoch [#.................................................]  3.86%
#         40 iter, 0 epoch / 2 epochs
#     3.7152 iters/sec. Estimated time to finish: 0:14:36.397107.
#      total [#.................................................]  2.23%
# this epoch [##................................................]  4.46%
#         50 iter, 0 epoch / 2 epochs
#     3.7923 iters/sec. Estimated time to finish: 0:14:15.934232.
#      total [#.................................................]  2.53%
# this epoch [##................................................]  5.06%
#         60 iter, 0 epoch / 2 epochs
#      3.594 iters/sec. Estimated time to finish: 0:15:00.369524.
#      total [#.................................................]  2.83%
# this epoch [##................................................]  5.66%
#         70 iter, 0 epoch / 2 epochs
#     3.6466 iters/sec. Estimated time to finish: 0:14:44.641066.
#      total [#.................................................]  3.13%
# this epoch [###...............................................]  6.27%
#         80 iter, 0 epoch / 2 epochs
#     3.6838 iters/sec. Estimated time to finish: 0:14:33.012336.
#      total [#.................................................]  3.43%
# this epoch [###...............................................]  6.87%
#         90 iter, 0 epoch / 2 epochs
#     3.7142 iters/sec. Estimated time to finish: 0:14:23.174432.
#      total [#.................................................]  3.73%
# this epoch [###...............................................]  7.47%
#        100 iter, 0 epoch / 2 epochs
#     3.7168 iters/sec. Estimated time to finish: 0:14:19.859090.
#      total [##................................................]  4.04%
# this epoch [####..............................................]  8.07%
#        110 iter, 0 epoch / 2 epochs
#     3.6452 iters/sec. Estimated time to finish: 0:14:34.022038.
#      total [##................................................]  4.34%
# this epoch [####..............................................]  8.67%
#        120 iter, 0 epoch / 2 epochs
#     3.6608 iters/sec. Estimated time to finish: 0:14:27.548500.
#      total [##................................................]  4.64%
# this epoch [####..............................................]  9.28%
#        130 iter, 0 epoch / 2 epochs
#     3.6757 iters/sec. Estimated time to finish: 0:14:21.328337.
#      total [##................................................]  4.94%
# this epoch [####..............................................]  9.88%
#        140 iter, 0 epoch / 2 epochs
#     3.7007 iters/sec. Estimated time to finish: 0:14:12.802231.
#      total [##................................................]  5.24%
# this epoch [#####.............................................] 10.48%
#        150 iter, 0 epoch / 2 epochs
#     3.6506 iters/sec. Estimated time to finish: 0:14:21.759377.
#      total [##................................................]  5.54%
# this epoch [#####.............................................] 11.08%
#        160 iter, 0 epoch / 2 epochs
#     3.6559 iters/sec. Estimated time to finish: 0:14:17.782166.
#      total [##................................................]  5.84%
# this epoch [#####.............................................] 11.69%
#        170 iter, 0 epoch / 2 epochs
#     3.6716 iters/sec. Estimated time to finish: 0:14:11.395995.
#      total [###...............................................]  6.14%
# this epoch [######............................................] 12.29%
#        180 iter, 0 epoch / 2 epochs
#     3.6613 iters/sec. Estimated time to finish: 0:14:11.058711.
#      total [###...............................................]  6.45%
# this epoch [######............................................] 12.89%
#        190 iter, 0 epoch / 2 epochs
#     3.6315 iters/sec. Estimated time to finish: 0:14:15.294142.
#      total [###...............................................]  6.75%
# this epoch [######............................................] 13.49%
#        200 iter, 0 epoch / 2 epochs
#     3.5732 iters/sec. Estimated time to finish: 0:14:26.446182.
#      total [###...............................................]  7.05%
# this epoch [#######...........................................] 14.10%
#        210 iter, 0 epoch / 2 epochs
#     3.5726 iters/sec. Estimated time to finish: 0:14:23.781469.
#      total [###...............................................]  7.35%
# this epoch [#######...........................................] 14.70%
#        220 iter, 0 epoch / 2 epochs
#     3.5907 iters/sec. Estimated time to finish: 0:14:16.651590.
#      total [###...............................................]  7.65%
# this epoch [#######...........................................] 15.30%
#        230 iter, 0 epoch / 2 epochs
#      3.597 iters/sec. Estimated time to finish: 0:14:12.364056.
#      total [###...............................................]  7.95%
# this epoch [#######...........................................] 15.90%
#        240 iter, 0 epoch / 2 epochs
#     3.5659 iters/sec. Estimated time to finish: 0:14:17.000213.
#      total [####..............................................]  8.25%
# this epoch [########..........................................] 16.51%
#        250 iter, 0 epoch / 2 epochs
#     3.5795 iters/sec. Estimated time to finish: 0:14:10.942244.
#      total [####..............................................]  8.55%
# this epoch [########..........................................] 17.11%
#        260 iter, 0 epoch / 2 epochs
#     3.5912 iters/sec. Estimated time to finish: 0:14:05.382436.
#      total [####..............................................]  8.86%
# this epoch [########..........................................] 17.71%
#        270 iter, 0 epoch / 2 epochs
#     3.6019 iters/sec. Estimated time to finish: 0:14:00.095902.
#      total [####..............................................]  9.16%
# this epoch [#########.........................................] 18.31%
#        280 iter, 0 epoch / 2 epochs
#     3.5934 iters/sec. Estimated time to finish: 0:13:59.297552.
#      total [####..............................................]  9.46%
# this epoch [#########.........................................] 18.92%
#        290 iter, 0 epoch / 2 epochs
#     3.5844 iters/sec. Estimated time to finish: 0:13:58.628182.
#      total [####..............................................]  9.76%
# this epoch [#########.........................................] 19.52%
#        300 iter, 0 epoch / 2 epochs
#     3.5959 iters/sec. Estimated time to finish: 0:13:53.151097.
#      total [#####.............................................] 10.06%
# this epoch [##########........................................] 20.12%
#        310 iter, 0 epoch / 2 epochs
#     3.6096 iters/sec. Estimated time to finish: 0:13:47.217379.
#      total [#####.............................................] 10.36%
# this epoch [##########........................................] 20.72%
#        320 iter, 0 epoch / 2 epochs
#      3.616 iters/sec. Estimated time to finish: 0:13:43.001077.
#      total [#####.............................................] 10.66%
# this epoch [##########........................................] 21.33%
#        330 iter, 0 epoch / 2 epochs
#     3.5927 iters/sec. Estimated time to finish: 0:13:45.556572.
#      total [#####.............................................] 10.96%
# this epoch [##########........................................] 21.93%
#        340 iter, 0 epoch / 2 epochs
#     3.6017 iters/sec. Estimated time to finish: 0:13:40.709474.
#      total [#####.............................................] 11.27%
# this epoch [###########.......................................] 22.53%
#        350 iter, 0 epoch / 2 epochs
#      3.611 iters/sec. Estimated time to finish: 0:13:35.819938.
#      total [#####.............................................] 11.57%
# this epoch [###########.......................................] 23.13%
#        360 iter, 0 epoch / 2 epochs
#     3.6199 iters/sec. Estimated time to finish: 0:13:31.057721.
#      total [#####.............................................] 11.87%
# this epoch [###########.......................................] 23.74%
#        370 iter, 0 epoch / 2 epochs
#     3.6209 iters/sec. Estimated time to finish: 0:13:28.067421.
#      total [######............................................] 12.17%
# this epoch [############......................................] 24.34%
#        380 iter, 0 epoch / 2 epochs
#     3.6039 iters/sec. Estimated time to finish: 0:13:29.105328.
#      total [######............................................] 12.47%
# this epoch [############......................................] 24.94%
#        390 iter, 0 epoch / 2 epochs
#     3.6119 iters/sec. Estimated time to finish: 0:13:24.545080.
#      total [######............................................] 12.77%
# this epoch [############......................................] 25.54%
#        400 iter, 0 epoch / 2 epochs
#     3.6211 iters/sec. Estimated time to finish: 0:13:19.740546.
#      total [######............................................] 13.07%
# this epoch [#############.....................................] 26.14%
#        410 iter, 0 epoch / 2 epochs
#     3.6295 iters/sec. Estimated time to finish: 0:13:15.148309.
#      total [######............................................] 13.37%
# this epoch [#############.....................................] 26.75%
#        420 iter, 0 epoch / 2 epochs
#     3.6177 iters/sec. Estimated time to finish: 0:13:14.975785.
#      total [######............................................] 13.67%
# this epoch [#############.....................................] 27.35%
#        430 iter, 0 epoch / 2 epochs
#     3.6209 iters/sec. Estimated time to finish: 0:13:11.499220.
#      total [######............................................] 13.98%
# this epoch [#############.....................................] 27.95%
#        440 iter, 0 epoch / 2 epochs
#     3.6262 iters/sec. Estimated time to finish: 0:13:07.587955.
#      total [#######...........................................] 14.28%
# this epoch [##############....................................] 28.55%
#        450 iter, 0 epoch / 2 epochs
#     3.6346 iters/sec. Estimated time to finish: 0:13:03.010371.
#      total [#######...........................................] 14.58%
# this epoch [##############....................................] 29.16%
#        460 iter, 0 epoch / 2 epochs
#     3.6391 iters/sec. Estimated time to finish: 0:12:59.300915.
#      total [#######...........................................] 14.88%
# this epoch [##############....................................] 29.76%
#        470 iter, 0 epoch / 2 epochs
#     3.6242 iters/sec. Estimated time to finish: 0:12:59.749999.
#      total [#######...........................................] 15.18%
# this epoch [###############...................................] 30.36%
#        480 iter, 0 epoch / 2 epochs
#     3.6305 iters/sec. Estimated time to finish: 0:12:55.650546.
#      total [#######...........................................] 15.48%
# this epoch [###############...................................] 30.96%
#        490 iter, 0 epoch / 2 epochs
#     3.6378 iters/sec. Estimated time to finish: 0:12:51.325082.
# epoch       iteration   perplexity  val_perplexity
# 0           500         520.754
#      total [#######...........................................] 15.78%
# this epoch [###############...................................] 31.57%
#        500 iter, 0 epoch / 2 epochs
#     3.6391 iters/sec. Estimated time to finish: 0:12:48.312221.
#      total [########..........................................] 16.08%
# this epoch [################..................................] 32.17%
#        510 iter, 0 epoch / 2 epochs
#     3.6367 iters/sec. Estimated time to finish: 0:12:46.075532.
#      total [########..........................................] 16.39%
# this epoch [################..................................] 32.77%
#        520 iter, 0 epoch / 2 epochs
#     3.6303 iters/sec. Estimated time to finish: 0:12:44.658522.
#      total [########..........................................] 16.69%
# this epoch [################..................................] 33.37%
#        530 iter, 0 epoch / 2 epochs
#     3.6374 iters/sec. Estimated time to finish: 0:12:40.427995.
#      total [########..........................................] 16.99%
# this epoch [################..................................] 33.98%
#        540 iter, 0 epoch / 2 epochs
#     3.6422 iters/sec. Estimated time to finish: 0:12:36.666560.
#      total [########..........................................] 17.29%
# this epoch [#################.................................] 34.58%
#        550 iter, 0 epoch / 2 epochs
#     3.6492 iters/sec. Estimated time to finish: 0:12:32.485874.
#      total [########..........................................] 17.59%
# this epoch [#################.................................] 35.18%
#        560 iter, 0 epoch / 2 epochs
#     3.6346 iters/sec. Estimated time to finish: 0:12:32.761709.
#      total [########..........................................] 17.89%
# this epoch [#################.................................] 35.78%
#        570 iter, 0 epoch / 2 epochs
#     3.6411 iters/sec. Estimated time to finish: 0:12:28.661571.
#      total [#########.........................................] 18.19%
# this epoch [##################................................] 36.39%
#        580 iter, 0 epoch / 2 epochs
#     3.6459 iters/sec. Estimated time to finish: 0:12:24.931410.
#      total [#########.........................................] 18.49%
# this epoch [##################................................] 36.99%
#        590 iter, 0 epoch / 2 epochs
#     3.6518 iters/sec. Estimated time to finish: 0:12:20.995216.
#      total [#########.........................................] 18.80%
# this epoch [##################................................] 37.59%
#        600 iter, 0 epoch / 2 epochs
#     3.6538 iters/sec. Estimated time to finish: 0:12:17.855051.
#      total [#########.........................................] 19.10%
# this epoch [###################...............................] 38.19%
#        610 iter, 0 epoch / 2 epochs
#     3.6439 iters/sec. Estimated time to finish: 0:12:17.109787.
#      total [#########.........................................] 19.40%
# this epoch [###################...............................] 38.80%
#        620 iter, 0 epoch / 2 epochs
#     3.6469 iters/sec. Estimated time to finish: 0:12:13.770312.
#      total [#########.........................................] 19.70%
# this epoch [###################...............................] 39.40%
#        630 iter, 0 epoch / 2 epochs
#      3.651 iters/sec. Estimated time to finish: 0:12:10.206656.
#      total [##########........................................] 20.00%
# this epoch [####################..............................] 40.00%
#        640 iter, 0 epoch / 2 epochs
#      3.656 iters/sec. Estimated time to finish: 0:12:06.457613.
#      total [##########........................................] 20.30%
# this epoch [####################..............................] 40.60%
#        650 iter, 0 epoch / 2 epochs
#     3.6487 iters/sec. Estimated time to finish: 0:12:05.183705.
#      total [##########........................................] 20.60%
# this epoch [####################..............................] 41.21%
#        660 iter, 0 epoch / 2 epochs
#     3.6436 iters/sec. Estimated time to finish: 0:12:03.441425.
#      total [##########........................................] 20.90%
# this epoch [####################..............................] 41.81%
#        670 iter, 0 epoch / 2 epochs
#     3.6468 iters/sec. Estimated time to finish: 0:12:00.063651.
#      total [##########........................................] 21.21%
# this epoch [#####################.............................] 42.41%
#        680 iter, 0 epoch / 2 epochs
#     3.6506 iters/sec. Estimated time to finish: 0:11:56.584573.
#      total [##########........................................] 21.51%
# this epoch [#####################.............................] 43.01%
#        690 iter, 0 epoch / 2 epochs
#     3.6529 iters/sec. Estimated time to finish: 0:11:53.388550.
#      total [##########........................................] 21.81%
# this epoch [#####################.............................] 43.61%
#        700 iter, 0 epoch / 2 epochs
#     3.6412 iters/sec. Estimated time to finish: 0:11:52.947901.
#      total [###########.......................................] 22.11%
# this epoch [######################............................] 44.22%
#        710 iter, 0 epoch / 2 epochs
#     3.6442 iters/sec. Estimated time to finish: 0:11:49.607112.
#      total [###########.......................................] 22.41%
# this epoch [######################............................] 44.82%
#        720 iter, 0 epoch / 2 epochs
#     3.6401 iters/sec. Estimated time to finish: 0:11:47.665330.
#      total [###########.......................................] 22.71%
# this epoch [######################............................] 45.42%
#        730 iter, 0 epoch / 2 epochs
#      3.643 iters/sec. Estimated time to finish: 0:11:44.354620.
#      total [###########.......................................] 23.01%
# this epoch [#######################...........................] 46.02%
#        740 iter, 0 epoch / 2 epochs
#     3.6356 iters/sec. Estimated time to finish: 0:11:43.033526.
#      total [###########.......................................] 23.31%
# this epoch [#######################...........................] 46.63%
#        750 iter, 0 epoch / 2 epochs
#      3.637 iters/sec. Estimated time to finish: 0:11:40.017275.
#      total [###########.......................................] 23.61%
# this epoch [#######################...........................] 47.23%
#        760 iter, 0 epoch / 2 epochs
#     3.6399 iters/sec. Estimated time to finish: 0:11:36.715515.
#      total [###########.......................................] 23.92%
# this epoch [#######################...........................] 47.83%
#        770 iter, 0 epoch / 2 epochs
#     3.6433 iters/sec. Estimated time to finish: 0:11:33.323213.
#      total [############......................................] 24.22%
# this epoch [########################..........................] 48.43%
#        780 iter, 0 epoch / 2 epochs
#     3.6471 iters/sec. Estimated time to finish: 0:11:29.855415.
#      total [############......................................] 24.52%
# this epoch [########################..........................] 49.04%
#        790 iter, 0 epoch / 2 epochs
#     3.6374 iters/sec. Estimated time to finish: 0:11:28.944691.
#      total [############......................................] 24.82%
# this epoch [########################..........................] 49.64%
#        800 iter, 0 epoch / 2 epochs
#      3.641 iters/sec. Estimated time to finish: 0:11:25.506101.
#      total [############......................................] 25.12%
# this epoch [#########################.........................] 50.24%
#        810 iter, 0 epoch / 2 epochs
#     3.6445 iters/sec. Estimated time to finish: 0:11:22.121912.
#      total [############......................................] 25.42%
# this epoch [#########################.........................] 50.84%
#        820 iter, 0 epoch / 2 epochs
#     3.6449 iters/sec. Estimated time to finish: 0:11:19.293943.
#      total [############......................................] 25.72%
# this epoch [#########################.........................] 51.45%
#        830 iter, 0 epoch / 2 epochs
#     3.6342 iters/sec. Estimated time to finish: 0:11:18.549797.
#      total [#############.....................................] 26.02%
# this epoch [##########################........................] 52.05%
#        840 iter, 0 epoch / 2 epochs
#     3.6302 iters/sec. Estimated time to finish: 0:11:16.535518.
#      total [#############.....................................] 26.33%
# this epoch [##########################........................] 52.65%
#        850 iter, 0 epoch / 2 epochs
#     3.6328 iters/sec. Estimated time to finish: 0:11:13.308059.
#      total [#############.....................................] 26.63%
# this epoch [##########################........................] 53.25%
#        860 iter, 0 epoch / 2 epochs
#     3.6339 iters/sec. Estimated time to finish: 0:11:10.341640.
#      total [#############.....................................] 26.93%
# this epoch [##########################........................] 53.86%
#        870 iter, 0 epoch / 2 epochs
#     3.6279 iters/sec. Estimated time to finish: 0:11:08.692466.
#      total [#############.....................................] 27.23%
# this epoch [###########################.......................] 54.46%
#        880 iter, 0 epoch / 2 epochs
#     3.6204 iters/sec. Estimated time to finish: 0:11:07.310051.
#      total [#############.....................................] 27.53%
# this epoch [###########################.......................] 55.06%
#        890 iter, 0 epoch / 2 epochs
#     3.6228 iters/sec. Estimated time to finish: 0:11:04.125234.
#      total [#############.....................................] 27.83%
# this epoch [###########################.......................] 55.66%
#        900 iter, 0 epoch / 2 epochs
#     3.6249 iters/sec. Estimated time to finish: 0:11:00.981250.
#      total [##############....................................] 28.13%
# this epoch [############################......................] 56.27%
#        910 iter, 0 epoch / 2 epochs
#     3.6253 iters/sec. Estimated time to finish: 0:10:58.136685.
#      total [##############....................................] 28.43%
# this epoch [############################......................] 56.87%
#        920 iter, 0 epoch / 2 epochs
#     3.6054 iters/sec. Estimated time to finish: 0:10:59.000586.
#      total [##############....................................] 28.74%
# this epoch [############################......................] 57.47%
#        930 iter, 0 epoch / 2 epochs
#     3.6071 iters/sec. Estimated time to finish: 0:10:55.924007.
#      total [##############....................................] 29.04%
# this epoch [#############################.....................] 58.07%
#        940 iter, 0 epoch / 2 epochs
#     3.6097 iters/sec. Estimated time to finish: 0:10:52.680625.
#      total [##############....................................] 29.34%
# this epoch [#############################.....................] 58.68%
#        950 iter, 0 epoch / 2 epochs
#     3.6094 iters/sec. Estimated time to finish: 0:10:49.949915.
#      total [##############....................................] 29.64%
# this epoch [#############################.....................] 59.28%
#        960 iter, 0 epoch / 2 epochs
#     3.5953 iters/sec. Estimated time to finish: 0:10:49.734510.
#      total [##############....................................] 29.94%
# this epoch [#############################.....................] 59.88%
#        970 iter, 0 epoch / 2 epochs
#     3.5958 iters/sec. Estimated time to finish: 0:10:46.856859.
#      total [###############...................................] 30.24%
# this epoch [##############################....................] 60.48%
#        980 iter, 0 epoch / 2 epochs
#     3.5985 iters/sec. Estimated time to finish: 0:10:43.589363.
#      total [###############...................................] 30.54%
# this epoch [##############################....................] 61.09%
#        990 iter, 0 epoch / 2 epochs
#     3.6002 iters/sec. Estimated time to finish: 0:10:40.505742.
# 0           1000        296.338
#      total [###############...................................] 30.84%
# this epoch [##############################....................] 61.69%
#       1000 iter, 0 epoch / 2 epochs
#     3.5968 iters/sec. Estimated time to finish: 0:10:38.338235.
#      total [###############...................................] 31.14%
# this epoch [###############################...................] 62.29%
#       1010 iter, 0 epoch / 2 epochs
#     3.5895 iters/sec. Estimated time to finish: 0:10:36.849938.
#      total [###############...................................] 31.45%
# this epoch [###############################...................] 62.89%
#       1020 iter, 0 epoch / 2 epochs
#     3.5717 iters/sec. Estimated time to finish: 0:10:37.221127.
#      total [###############...................................] 31.75%
# this epoch [###############################...................] 63.49%
#       1030 iter, 0 epoch / 2 epochs
#     3.5597 iters/sec. Estimated time to finish: 0:10:36.557468.
#      total [################..................................] 32.05%
# this epoch [################################..................] 64.10%
#       1040 iter, 0 epoch / 2 epochs
#     3.5419 iters/sec. Estimated time to finish: 0:10:36.929503.
#      total [################..................................] 32.35%
# this epoch [################################..................] 64.70%
#       1050 iter, 0 epoch / 2 epochs
#     3.5185 iters/sec. Estimated time to finish: 0:10:38.321610.
#      total [################..................................] 32.65%
# this epoch [################################..................] 65.30%
#       1060 iter, 0 epoch / 2 epochs
#     3.4933 iters/sec. Estimated time to finish: 0:10:40.062642.
#      total [################..................................] 32.95%
# this epoch [################################..................] 65.90%
#       1070 iter, 0 epoch / 2 epochs
#     3.4589 iters/sec. Estimated time to finish: 0:10:43.542445.
#      total [################..................................] 33.25%
# this epoch [#################################.................] 66.51%
#       1080 iter, 0 epoch / 2 epochs
#     3.4504 iters/sec. Estimated time to finish: 0:10:42.237070.
#      total [################..................................] 33.55%
# this epoch [#################################.................] 67.11%
#       1090 iter, 0 epoch / 2 epochs
#     3.4412 iters/sec. Estimated time to finish: 0:10:41.047536.
#      total [################..................................] 33.86%
# this epoch [#################################.................] 67.71%
#       1100 iter, 0 epoch / 2 epochs
#     3.4382 iters/sec. Estimated time to finish: 0:10:38.693060.
#      total [#################.................................] 34.16%
# this epoch [##################################................] 68.31%
#       1110 iter, 0 epoch / 2 epochs
#     3.4151 iters/sec. Estimated time to finish: 0:10:40.091980.
#      total [#################.................................] 34.46%
# this epoch [##################################................] 68.92%
#       1120 iter, 0 epoch / 2 epochs
#     3.3916 iters/sec. Estimated time to finish: 0:10:41.574668.
#      total [#################.................................] 34.76%
# this epoch [##################################................] 69.52%
#       1130 iter, 0 epoch / 2 epochs
#     3.3677 iters/sec. Estimated time to finish: 0:10:43.160901.
#      total [#################.................................] 35.06%
# this epoch [###################################...............] 70.12%
#       1140 iter, 0 epoch / 2 epochs
#     3.3763 iters/sec. Estimated time to finish: 0:10:38.561453.
#      total [#################.................................] 35.36%
# this epoch [###################################...............] 70.72%
#       1150 iter, 0 epoch / 2 epochs
#     3.3783 iters/sec. Estimated time to finish: 0:10:35.216918.
#      total [#################.................................] 35.66%
# this epoch [###################################...............] 71.33%
#       1160 iter, 0 epoch / 2 epochs
#      3.379 iters/sec. Estimated time to finish: 0:10:32.122411.
#      total [#################.................................] 35.96%
# this epoch [###################################...............] 71.93%
#       1170 iter, 0 epoch / 2 epochs
#     3.3762 iters/sec. Estimated time to finish: 0:10:29.685893.
#      total [##################................................] 36.27%
# this epoch [####################################..............] 72.53%
#       1180 iter, 0 epoch / 2 epochs
#     3.3787 iters/sec. Estimated time to finish: 0:10:26.259852.
#      total [##################................................] 36.57%
# this epoch [####################################..............] 73.13%
#       1190 iter, 0 epoch / 2 epochs
#     3.3899 iters/sec. Estimated time to finish: 0:10:21.246374.
#      total [##################................................] 36.87%
# this epoch [####################################..............] 73.74%
#       1200 iter, 0 epoch / 2 epochs
#      3.393 iters/sec. Estimated time to finish: 0:10:17.726883.
#      total [##################................................] 37.17%
# this epoch [#####################################.............] 74.34%
#       1210 iter, 0 epoch / 2 epochs
#     3.3916 iters/sec. Estimated time to finish: 0:10:15.037582.
#      total [##################................................] 37.47%
# this epoch [#####################################.............] 74.94%
#       1220 iter, 0 epoch / 2 epochs
#     3.3825 iters/sec. Estimated time to finish: 0:10:13.730765.
#      total [##################................................] 37.77%
# this epoch [#####################################.............] 75.54%
#       1230 iter, 0 epoch / 2 epochs
#     3.3911 iters/sec. Estimated time to finish: 0:10:09.221936.
#      total [###################...............................] 38.07%
# this epoch [######################################............] 76.15%
#       1240 iter, 0 epoch / 2 epochs
#       3.39 iters/sec. Estimated time to finish: 0:10:06.469426.
#      total [###################...............................] 38.37%
# this epoch [######################################............] 76.75%
#       1250 iter, 0 epoch / 2 epochs
#     3.3884 iters/sec. Estimated time to finish: 0:10:03.811725.
#      total [###################...............................] 38.68%
# this epoch [######################################............] 77.35%
#       1260 iter, 0 epoch / 2 epochs
#     3.3832 iters/sec. Estimated time to finish: 0:10:01.781895.
#      total [###################...............................] 38.98%
# this epoch [######################################............] 77.95%
#       1270 iter, 0 epoch / 2 epochs
#     3.3827 iters/sec. Estimated time to finish: 0:09:58.912788.
#      total [###################...............................] 39.28%
# this epoch [#######################################...........] 78.56%
#       1280 iter, 0 epoch / 2 epochs
#     3.3877 iters/sec. Estimated time to finish: 0:09:55.088934.
#      total [###################...............................] 39.58%
# this epoch [#######################################...........] 79.16%
#       1290 iter, 0 epoch / 2 epochs
#     3.3881 iters/sec. Estimated time to finish: 0:09:52.055825.
#      total [###################...............................] 39.88%
# this epoch [#######################################...........] 79.76%
#       1300 iter, 0 epoch / 2 epochs
#     3.3869 iters/sec. Estimated time to finish: 0:09:49.322011.
#      total [####################..............................] 40.18%
# this epoch [########################################..........] 80.36%
#       1310 iter, 0 epoch / 2 epochs
#     3.3791 iters/sec. Estimated time to finish: 0:09:47.711609.
#      total [####################..............................] 40.48%
# this epoch [########################################..........] 80.96%
#       1320 iter, 0 epoch / 2 epochs
#     3.3879 iters/sec. Estimated time to finish: 0:09:43.242312.
#      total [####################..............................] 40.78%
# this epoch [########################################..........] 81.57%
#       1330 iter, 0 epoch / 2 epochs
#     3.3887 iters/sec. Estimated time to finish: 0:09:40.150422.
#      total [####################..............................] 41.08%
# this epoch [#########################################.........] 82.17%
#       1340 iter, 0 epoch / 2 epochs
#      3.389 iters/sec. Estimated time to finish: 0:09:37.156236.
#      total [####################..............................] 41.39%
# this epoch [#########################################.........] 82.77%
#       1350 iter, 0 epoch / 2 epochs
#     3.3853 iters/sec. Estimated time to finish: 0:09:34.823426.
#      total [####################..............................] 41.69%
# this epoch [#########################################.........] 83.37%
#       1360 iter, 0 epoch / 2 epochs
#     3.3812 iters/sec. Estimated time to finish: 0:09:32.558496.
#      total [####################..............................] 41.99%
# this epoch [#########################################.........] 83.98%
#       1370 iter, 0 epoch / 2 epochs
#     3.3895 iters/sec. Estimated time to finish: 0:09:28.216312.
#      total [#####################.............................] 42.29%
# this epoch [##########################################........] 84.58%
#       1380 iter, 0 epoch / 2 epochs
#     3.3891 iters/sec. Estimated time to finish: 0:09:25.335566.
#      total [#####################.............................] 42.59%
# this epoch [##########################################........] 85.18%
#       1390 iter, 0 epoch / 2 epochs
#     3.3886 iters/sec. Estimated time to finish: 0:09:22.466857.
#      total [#####################.............................] 42.89%
# this epoch [##########################################........] 85.78%
#       1400 iter, 0 epoch / 2 epochs
#     3.3799 iters/sec. Estimated time to finish: 0:09:20.955945.
#      total [#####################.............................] 43.19%
# this epoch [###########################################.......] 86.39%
#       1410 iter, 0 epoch / 2 epochs
#     3.3849 iters/sec. Estimated time to finish: 0:09:17.171603.
#      total [#####################.............................] 43.49%
# this epoch [###########################################.......] 86.99%
#       1420 iter, 0 epoch / 2 epochs
#     3.3861 iters/sec. Estimated time to finish: 0:09:14.021198.
#      total [#####################.............................] 43.80%
# this epoch [###########################################.......] 87.59%
#       1430 iter, 0 epoch / 2 epochs
#     3.3867 iters/sec. Estimated time to finish: 0:09:10.972962.
#      total [######################............................] 44.10%
# this epoch [############################################......] 88.19%
#       1440 iter, 0 epoch / 2 epochs
#     3.3854 iters/sec. Estimated time to finish: 0:09:08.220063.
#      total [######################............................] 44.40%
# this epoch [############################################......] 88.80%
#       1450 iter, 0 epoch / 2 epochs
#     3.3771 iters/sec. Estimated time to finish: 0:09:06.618247.
#      total [######################............................] 44.70%
# this epoch [############################################......] 89.40%
#       1460 iter, 0 epoch / 2 epochs
#      3.385 iters/sec. Estimated time to finish: 0:09:02.377615.
#      total [######################............................] 45.00%
# this epoch [#############################################.....] 90.00%
#       1470 iter, 0 epoch / 2 epochs
#     3.3851 iters/sec. Estimated time to finish: 0:08:59.418682.
#      total [######################............................] 45.30%
# this epoch [#############################################.....] 90.60%
#       1480 iter, 0 epoch / 2 epochs
#     3.3824 iters/sec. Estimated time to finish: 0:08:56.892371.
#      total [######################............................] 45.60%
# this epoch [#############################################.....] 91.21%
#       1490 iter, 0 epoch / 2 epochs
#     3.3558 iters/sec. Estimated time to finish: 0:08:58.164372.
# 0           1500        242.689
#      total [######################............................] 45.90%
# this epoch [#############################################.....] 91.81%
#       1500 iter, 0 epoch / 2 epochs
#     3.3349 iters/sec. Estimated time to finish: 0:08:58.538017.
#      total [#######################...........................] 46.21%
# this epoch [##############################################....] 92.41%
#       1510 iter, 0 epoch / 2 epochs
#     3.3342 iters/sec. Estimated time to finish: 0:08:55.644148.
#      total [#######################...........................] 46.51%
# this epoch [##############################################....] 93.01%
#       1520 iter, 0 epoch / 2 epochs
#     3.3291 iters/sec. Estimated time to finish: 0:08:53.464419.
#      total [#######################...........................] 46.81%
# this epoch [##############################################....] 93.62%
#       1530 iter, 0 epoch / 2 epochs
#     3.3177 iters/sec. Estimated time to finish: 0:08:52.285004.
#      total [#######################...........................] 47.11%
# this epoch [###############################################...] 94.22%
#       1540 iter, 0 epoch / 2 epochs
#     3.3127 iters/sec. Estimated time to finish: 0:08:50.065895.
#      total [#######################...........................] 47.41%
# this epoch [###############################################...] 94.82%
#       1550 iter, 0 epoch / 2 epochs
#     3.3224 iters/sec. Estimated time to finish: 0:08:45.515072.
#      total [#######################...........................] 47.71%
# this epoch [###############################################...] 95.42%
#       1560 iter, 0 epoch / 2 epochs
#     3.2949 iters/sec. Estimated time to finish: 0:08:46.855373.
#      total [########################..........................] 48.01%
# this epoch [################################################..] 96.03%
#       1570 iter, 0 epoch / 2 epochs
#     3.2813 iters/sec. Estimated time to finish: 0:08:45.993187.
#      total [########################..........................] 48.31%
# this epoch [################################################..] 96.63%
#       1580 iter, 0 epoch / 2 epochs
#     3.2803 iters/sec. Estimated time to finish: 0:08:43.103800.
#      total [########################..........................] 48.62%
# this epoch [################################################..] 97.23%
#       1590 iter, 0 epoch / 2 epochs
#     3.2703 iters/sec. Estimated time to finish: 0:08:41.654143.
#      total [########################..........................] 48.92%
# this epoch [################################################..] 97.83%
#       1600 iter, 0 epoch / 2 epochs
#     3.2477 iters/sec. Estimated time to finish: 0:08:42.200946.
#      total [########################..........................] 49.22%
# this epoch [#################################################.] 98.43%
#       1610 iter, 0 epoch / 2 epochs
#     3.2464 iters/sec. Estimated time to finish: 0:08:39.332435.
#      total [########################..........................] 49.52%
# this epoch [#################################################.] 99.04%
#       1620 iter, 0 epoch / 2 epochs
#     3.2467 iters/sec. Estimated time to finish: 0:08:36.198501.
#      total [########################..........................] 49.82%
# this epoch [#################################################.] 99.64%
#       1630 iter, 0 epoch / 2 epochs
#     3.2473 iters/sec. Estimated time to finish: 0:08:33.023023.
#      total [#########################.........................] 50.12%
# this epoch [..................................................]  0.24%
#       1640 iter, 1 epoch / 2 epochs
#      1.807 iters/sec. Estimated time to finish: 0:15:16.406826.
#      total [#########################.........................] 50.42%
# this epoch [..................................................]  0.84%
#       1650 iter, 1 epoch / 2 epochs
#     1.8084 iters/sec. Estimated time to finish: 0:15:10.196302.
#      total [#########################.........................] 50.72%
# this epoch [..................................................]  1.45%
#       1660 iter, 1 epoch / 2 epochs
#     1.8085 iters/sec. Estimated time to finish: 0:15:04.609664.
#      total [#########################.........................] 51.02%
# this epoch [#.................................................]  2.05%
#       1670 iter, 1 epoch / 2 epochs
#     1.8059 iters/sec. Estimated time to finish: 0:15:00.366646.
#      total [#########################.........................] 51.33%
# this epoch [#.................................................]  2.65%
#       1680 iter, 1 epoch / 2 epochs
#     1.8062 iters/sec. Estimated time to finish: 0:14:54.694068.
#      total [#########################.........................] 51.63%
# this epoch [#.................................................]  3.25%
#       1690 iter, 1 epoch / 2 epochs
#     1.8086 iters/sec. Estimated time to finish: 0:14:47.937667.
#      total [#########################.........................] 51.93%
# this epoch [#.................................................]  3.86%
#       1700 iter, 1 epoch / 2 epochs
#      1.809 iters/sec. Estimated time to finish: 0:14:42.257348.
#      total [##########################........................] 52.23%
# this epoch [##................................................]  4.46%
#       1710 iter, 1 epoch / 2 epochs
#     1.8088 iters/sec. Estimated time to finish: 0:14:36.825415.
#      total [##########################........................] 52.53%
# this epoch [##................................................]  5.06%
#       1720 iter, 1 epoch / 2 epochs
#     1.8079 iters/sec. Estimated time to finish: 0:14:31.727006.
#      total [##########################........................] 52.83%
# this epoch [##................................................]  5.66%
#       1730 iter, 1 epoch / 2 epochs
#       1.81 iters/sec. Estimated time to finish: 0:14:25.173021.
#      total [##########################........................] 53.13%
# this epoch [###...............................................]  6.27%
#       1740 iter, 1 epoch / 2 epochs
#     1.8103 iters/sec. Estimated time to finish: 0:14:19.527381.
#      total [##########################........................] 53.43%
# this epoch [###...............................................]  6.87%
#       1750 iter, 1 epoch / 2 epochs
#     1.8105 iters/sec. Estimated time to finish: 0:14:13.908588.
#      total [##########################........................] 53.74%
# this epoch [###...............................................]  7.47%
#       1760 iter, 1 epoch / 2 epochs
#     1.8078 iters/sec. Estimated time to finish: 0:14:09.643081.
#      total [###########################.......................] 54.04%
# this epoch [####..............................................]  8.07%
#       1770 iter, 1 epoch / 2 epochs
#     1.8078 iters/sec. Estimated time to finish: 0:14:04.112412.
#      total [###########################.......................] 54.34%
# this epoch [####..............................................]  8.68%
#       1780 iter, 1 epoch / 2 epochs
#     1.8102 iters/sec. Estimated time to finish: 0:13:57.470792.
#      total [###########################.......................] 54.64%
# this epoch [####..............................................]  9.28%
#       1790 iter, 1 epoch / 2 epochs
#     1.8103 iters/sec. Estimated time to finish: 0:13:51.861856.
#      total [###########################.......................] 54.94%
# this epoch [####..............................................]  9.88%
#       1800 iter, 1 epoch / 2 epochs
#     1.8096 iters/sec. Estimated time to finish: 0:13:46.685011.
#      total [###########################.......................] 55.24%
# this epoch [#####.............................................] 10.48%
#       1810 iter, 1 epoch / 2 epochs
#     1.8082 iters/sec. Estimated time to finish: 0:13:41.794801.
#      total [###########################.......................] 55.54%
# this epoch [#####.............................................] 11.09%
#       1820 iter, 1 epoch / 2 epochs
#      1.811 iters/sec. Estimated time to finish: 0:13:35.005511.
#      total [###########################.......................] 55.84%
# this epoch [#####.............................................] 11.69%
#       1830 iter, 1 epoch / 2 epochs
#     1.8126 iters/sec. Estimated time to finish: 0:13:28.766406.
#      total [############################......................] 56.15%
# this epoch [######............................................] 12.29%
#       1840 iter, 1 epoch / 2 epochs
#      1.813 iters/sec. Estimated time to finish: 0:13:23.085756.
#      total [############################......................] 56.45%
# this epoch [######............................................] 12.89%
#       1850 iter, 1 epoch / 2 epochs
#     1.8109 iters/sec. Estimated time to finish: 0:13:18.454281.
#      total [############################......................] 56.75%
# this epoch [######............................................] 13.50%
#       1860 iter, 1 epoch / 2 epochs
#     1.8125 iters/sec. Estimated time to finish: 0:13:12.242754.
#      total [############################......................] 57.05%
# this epoch [#######...........................................] 14.10%
#       1870 iter, 1 epoch / 2 epochs
#     1.8149 iters/sec. Estimated time to finish: 0:13:05.716346.
#      total [############################......................] 57.35%
# this epoch [#######...........................................] 14.70%
#       1880 iter, 1 epoch / 2 epochs
#     1.8153 iters/sec. Estimated time to finish: 0:13:00.015416.
#      total [############################......................] 57.65%
# this epoch [#######...........................................] 15.30%
#       1890 iter, 1 epoch / 2 epochs
#     1.8154 iters/sec. Estimated time to finish: 0:12:54.477360.
#      total [############################......................] 57.95%
# this epoch [#######...........................................] 15.90%
#       1900 iter, 1 epoch / 2 epochs
#     1.8132 iters/sec. Estimated time to finish: 0:12:49.866903.
#      total [#############################.....................] 58.25%
# this epoch [########..........................................] 16.51%
#       1910 iter, 1 epoch / 2 epochs
#     1.8184 iters/sec. Estimated time to finish: 0:12:42.169992.
#      total [#############################.....................] 58.55%
# this epoch [########..........................................] 17.11%
#       1920 iter, 1 epoch / 2 epochs
#     1.8187 iters/sec. Estimated time to finish: 0:12:36.581391.
#      total [#############################.....................] 58.86%
# this epoch [########..........................................] 17.71%
#       1930 iter, 1 epoch / 2 epochs
#     1.8189 iters/sec. Estimated time to finish: 0:12:30.963029.
#      total [#############################.....................] 59.16%
# this epoch [#########.........................................] 18.31%
#       1940 iter, 1 epoch / 2 epochs
#     1.8184 iters/sec. Estimated time to finish: 0:12:25.690319.
#      total [#############################.....................] 59.46%
# this epoch [#########.........................................] 18.92%
#       1950 iter, 1 epoch / 2 epochs
#     1.8213 iters/sec. Estimated time to finish: 0:12:19.026251.
#      total [#############################.....................] 59.76%
# this epoch [#########.........................................] 19.52%
#       1960 iter, 1 epoch / 2 epochs
#     1.8217 iters/sec. Estimated time to finish: 0:12:13.353889.
#      total [##############################....................] 60.06%
# this epoch [##########........................................] 20.12%
#       1970 iter, 1 epoch / 2 epochs
#     1.8212 iters/sec. Estimated time to finish: 0:12:08.057757.
#      total [##############################....................] 60.36%
# ...
# this epoch [##############################....................] 60.48%
#       2640 iter, 1 epoch / 2 epochs
#     3.6747 iters/sec. Estimated time to finish: 0:02:58.505514.
#      total [########################################..........] 80.54%
# this epoch [##############################....................] 61.09%
#       2650 iter, 1 epoch / 2 epochs
#     3.6744 iters/sec. Estimated time to finish: 0:02:55.800092.
#      total [########################################..........] 80.84%
# this epoch [##############################....................] 61.69%
#       2660 iter, 1 epoch / 2 epochs
#     3.6856 iters/sec. Estimated time to finish: 0:02:52.554094.
#      total [########################################..........] 81.15%
# this epoch [###############################...................] 62.29%
#       2670 iter, 1 epoch / 2 epochs
#     3.6852 iters/sec. Estimated time to finish: 0:02:49.858967.
#      total [########################################..........] 81.45%
# this epoch [###############################...................] 62.89%
#       2680 iter, 1 epoch / 2 epochs
#     3.6762 iters/sec. Estimated time to finish: 0:02:47.555698.
#      total [########################################..........] 81.75%
# this epoch [###############################...................] 63.50%
#       2690 iter, 1 epoch / 2 epochs
#     3.6745 iters/sec. Estimated time to finish: 0:02:44.909771.
#      total [#########################################.........] 82.05%
# this epoch [################################..................] 64.10%
#       2700 iter, 1 epoch / 2 epochs
#      3.681 iters/sec. Estimated time to finish: 0:02:41.901064.
#      total [#########################################.........] 82.35%
# this epoch [################################..................] 64.70%
#       2710 iter, 1 epoch / 2 epochs
#     3.6856 iters/sec. Estimated time to finish: 0:02:38.986318.
#      total [#########################################.........] 82.65%
# this epoch [################################..................] 65.30%
#       2720 iter, 1 epoch / 2 epochs
#      3.681 iters/sec. Estimated time to finish: 0:02:36.466935.
#      total [#########################################.........] 82.95%
# this epoch [################################..................] 65.91%
#       2730 iter, 1 epoch / 2 epochs
#     3.6745 iters/sec. Estimated time to finish: 0:02:34.024613.
#      total [#########################################.........] 83.25%
# this epoch [#################################.................] 66.51%
#       2740 iter, 1 epoch / 2 epochs
#     3.6734 iters/sec. Estimated time to finish: 0:02:31.346029.
#      total [#########################################.........] 83.56%
# this epoch [#################################.................] 67.11%
#       2750 iter, 1 epoch / 2 epochs
#      3.685 iters/sec. Estimated time to finish: 0:02:28.157110.
#      total [#########################################.........] 83.86%
# this epoch [#################################.................] 67.71%
#       2760 iter, 1 epoch / 2 epochs
#     3.6836 iters/sec. Estimated time to finish: 0:02:25.500141.
#      total [##########################################........] 84.16%
# this epoch [##################################................] 68.32%
#       2770 iter, 1 epoch / 2 epochs
#      3.673 iters/sec. Estimated time to finish: 0:02:23.197206.
#      total [##########################################........] 84.46%
# this epoch [##################################................] 68.92%
#       2780 iter, 1 epoch / 2 epochs
#     3.6713 iters/sec. Estimated time to finish: 0:02:20.537329.
#      total [##########################################........] 84.76%
# this epoch [##################################................] 69.52%
#       2790 iter, 1 epoch / 2 epochs
#     3.6753 iters/sec. Estimated time to finish: 0:02:17.665109.
#      total [##########################################........] 85.06%
# this epoch [###################################...............] 70.12%
#       2800 iter, 1 epoch / 2 epochs
#      3.683 iters/sec. Estimated time to finish: 0:02:14.661494.
#      total [##########################################........] 85.36%
# this epoch [###################################...............] 70.72%
#       2810 iter, 1 epoch / 2 epochs
#     3.6825 iters/sec. Estimated time to finish: 0:02:11.964825.
#      total [##########################################........] 85.66%
# this epoch [###################################...............] 71.33%
#       2820 iter, 1 epoch / 2 epochs
#     3.6717 iters/sec. Estimated time to finish: 0:02:09.628801.
#      total [##########################################........] 85.96%
# this epoch [###################################...............] 71.93%
#       2830 iter, 1 epoch / 2 epochs
#     3.6719 iters/sec. Estimated time to finish: 0:02:06.898554.
#      total [###########################################.......] 86.27%
# this epoch [####################################..............] 72.53%
#       2840 iter, 1 epoch / 2 epochs
#     3.6824 iters/sec. Estimated time to finish: 0:02:03.820677.
#      total [###########################################.......] 86.57%
# this epoch [####################################..............] 73.13%
#       2850 iter, 1 epoch / 2 epochs
#     3.6853 iters/sec. Estimated time to finish: 0:02:01.010855.
#      total [###########################################.......] 86.87%
# this epoch [####################################..............] 73.74%
#       2860 iter, 1 epoch / 2 epochs
#     3.6791 iters/sec. Estimated time to finish: 0:01:58.496519.
#      total [###########################################.......] 87.17%
# this epoch [#####################################.............] 74.34%
#       2870 iter, 1 epoch / 2 epochs
#     3.6741 iters/sec. Estimated time to finish: 0:01:55.935674.
#      total [###########################################.......] 87.47%
# this epoch [#####################################.............] 74.94%
#       2880 iter, 1 epoch / 2 epochs
#     3.6747 iters/sec. Estimated time to finish: 0:01:53.196141.
#      total [###########################################.......] 87.77%
# this epoch [#####################################.............] 75.54%
#       2890 iter, 1 epoch / 2 epochs
#     3.6866 iters/sec. Estimated time to finish: 0:01:50.116476.
#      total [############################################......] 88.07%
# this epoch [######################################............] 76.15%
#       2900 iter, 1 epoch / 2 epochs
#     3.6875 iters/sec. Estimated time to finish: 0:01:47.378507.
#      total [############################################......] 88.37%
# this epoch [######################################............] 76.75%
#       2910 iter, 1 epoch / 2 epochs
#     3.6765 iters/sec. Estimated time to finish: 0:01:44.981468.
#      total [############################################......] 88.68%
# this epoch [######################################............] 77.35%
#       2920 iter, 1 epoch / 2 epochs
#     3.6766 iters/sec. Estimated time to finish: 0:01:42.259044.
#      total [############################################......] 88.98%
# this epoch [######################################............] 77.95%
#       2930 iter, 1 epoch / 2 epochs
#      3.682 iters/sec. Estimated time to finish: 0:01:39.390856.
#      total [############################################......] 89.28%
# this epoch [#######################################...........] 78.56%
#       2940 iter, 1 epoch / 2 epochs
#     3.6871 iters/sec. Estimated time to finish: 0:01:36.541131.
#      total [############################################......] 89.58%
# this epoch [#######################################...........] 79.16%
#       2950 iter, 1 epoch / 2 epochs
#     3.6866 iters/sec. Estimated time to finish: 0:01:33.843743.
#      total [############################################......] 89.88%
# this epoch [#######################################...........] 79.76%
#       2960 iter, 1 epoch / 2 epochs
#     3.6805 iters/sec. Estimated time to finish: 0:01:31.281054.
#      total [#############################################.....] 90.18%
# this epoch [########################################..........] 80.36%
#       2970 iter, 1 epoch / 2 epochs
#     3.6812 iters/sec. Estimated time to finish: 0:01:28.548511.
#      total [#############################################.....] 90.48%
# this epoch [########################################..........] 80.97%
#       2980 iter, 1 epoch / 2 epochs
#      3.693 iters/sec. Estimated time to finish: 0:01:25.557411.
#      total [#############################################.....] 90.78%
# this epoch [########################################..........] 81.57%
#       2990 iter, 1 epoch / 2 epochs
#     3.6954 iters/sec. Estimated time to finish: 0:01:22.793904.
# 1           3000        170.13
#      total [#############################################.....] 91.09%
# this epoch [#########################################.........] 82.17%
#       3000 iter, 1 epoch / 2 epochs
#     3.6852 iters/sec. Estimated time to finish: 0:01:20.310395.
#      total [#############################################.....] 91.39%
# this epoch [#########################################.........] 82.77%
#       3010 iter, 1 epoch / 2 epochs
#     3.6827 iters/sec. Estimated time to finish: 0:01:17.649840.
#      total [#############################################.....] 91.69%
# this epoch [#########################################.........] 83.38%
#       3020 iter, 1 epoch / 2 epochs
#     3.6756 iters/sec. Estimated time to finish: 0:01:15.079916.
#      total [#############################################.....] 91.99%
# this epoch [#########################################.........] 83.98%
#       3030 iter, 1 epoch / 2 epochs
#     3.6822 iters/sec. Estimated time to finish: 0:01:12.229488.
#      total [##############################################....] 92.29%
# this epoch [##########################################........] 84.58%
#       3040 iter, 1 epoch / 2 epochs
#     3.6768 iters/sec. Estimated time to finish: 0:01:09.615057.
#      total [##############################################....] 92.59%
# this epoch [##########################################........] 85.18%
#       3050 iter, 1 epoch / 2 epochs
#     3.6698 iters/sec. Estimated time to finish: 0:01:07.023606.
#      total [##############################################....] 92.89%
# this epoch [##########################################........] 85.79%
#       3060 iter, 1 epoch / 2 epochs
#     3.6717 iters/sec. Estimated time to finish: 0:01:04.264810.
#      total [##############################################....] 93.19%
# this epoch [###########################################.......] 86.39%
#       3070 iter, 1 epoch / 2 epochs
#     3.6822 iters/sec. Estimated time to finish: 0:01:01.365058.
#      total [##############################################....] 93.50%
# this epoch [###########################################.......] 86.99%
#       3080 iter, 1 epoch / 2 epochs
#     3.6834 iters/sec. Estimated time to finish: 0:00:58.631042.
#      total [##############################################....] 93.80%
# this epoch [###########################################.......] 87.59%
#       3090 iter, 1 epoch / 2 epochs
#     3.6726 iters/sec. Estimated time to finish: 0:00:56.080971.
#      total [###############################################...] 94.10%
# this epoch [############################################......] 88.19%
#       3100 iter, 1 epoch / 2 epochs
#     3.6731 iters/sec. Estimated time to finish: 0:00:53.350745.
#      total [###############################################...] 94.40%
# this epoch [############################################......] 88.80%
#       3110 iter, 1 epoch / 2 epochs
#     3.6666 iters/sec. Estimated time to finish: 0:00:50.717028.
#      total [###############################################...] 94.70%
# this epoch [############################################......] 89.40%
#       3120 iter, 1 epoch / 2 epochs
#     3.6778 iters/sec. Estimated time to finish: 0:00:47.844504.
#      total [###############################################...] 95.00%
# this epoch [#############################################.....] 90.00%
#       3130 iter, 1 epoch / 2 epochs
#     3.6731 iters/sec. Estimated time to finish: 0:00:45.182473.
#      total [###############################################...] 95.30%
# this epoch [#############################################.....] 90.60%
#       3140 iter, 1 epoch / 2 epochs
#      3.667 iters/sec. Estimated time to finish: 0:00:42.530543.
#      total [###############################################...] 95.60%
# this epoch [#############################################.....] 91.21%
#       3150 iter, 1 epoch / 2 epochs
#     3.6684 iters/sec. Estimated time to finish: 0:00:39.789061.
#      total [###############################################...] 95.90%
# this epoch [#############################################.....] 91.81%
#       3160 iter, 1 epoch / 2 epochs
#     3.6513 iters/sec. Estimated time to finish: 0:00:37.235901.
#      total [################################################..] 96.21%
# this epoch [##############################################....] 92.41%
#       3170 iter, 1 epoch / 2 epochs
#     3.5878 iters/sec. Estimated time to finish: 0:00:35.107996.
#      total [################################################..] 96.51%
# this epoch [##############################################....] 93.01%
#       3180 iter, 1 epoch / 2 epochs
#     3.5663 iters/sec. Estimated time to finish: 0:00:32.515250.
#      total [################################################..] 96.81%
# this epoch [##############################################....] 93.62%
#       3190 iter, 1 epoch / 2 epochs
#      3.566 iters/sec. Estimated time to finish: 0:00:29.713765.
#      total [################################################..] 97.11%
# this epoch [###############################################...] 94.22%
#       3200 iter, 1 epoch / 2 epochs
#     3.5574 iters/sec. Estimated time to finish: 0:00:26.975240.
#      total [################################################..] 97.41%
# this epoch [###############################################...] 94.82%
#       3210 iter, 1 epoch / 2 epochs
#     3.5672 iters/sec. Estimated time to finish: 0:00:24.097470.
#      total [################################################..] 97.71%
# this epoch [###############################################...] 95.42%
#       3220 iter, 1 epoch / 2 epochs
#     3.5673 iters/sec. Estimated time to finish: 0:00:21.293481.
#      total [#################################################.] 98.01%
# this epoch [################################################..] 96.03%
#       3230 iter, 1 epoch / 2 epochs
#     3.5668 iters/sec. Estimated time to finish: 0:00:18.493173.
#      total [#################################################.] 98.31%
# this epoch [################################################..] 96.63%
#       3240 iter, 1 epoch / 2 epochs
#     3.5653 iters/sec. Estimated time to finish: 0:00:15.695898.
#      total [#################################################.] 98.62%
# this epoch [################################################..] 97.23%
#       3250 iter, 1 epoch / 2 epochs
#     3.5615 iters/sec. Estimated time to finish: 0:00:12.904922.
#      total [#################################################.] 98.92%
# this epoch [################################################..] 97.83%
#       3260 iter, 1 epoch / 2 epochs
#     3.5682 iters/sec. Estimated time to finish: 0:00:10.078065.
#      total [#################################################.] 99.22%
# this epoch [#################################################.] 98.44%
#       3270 iter, 1 epoch / 2 epochs
#     3.5684 iters/sec. Estimated time to finish: 0:00:07.275095.
#      total [#################################################.] 99.52%
# this epoch [#################################################.] 99.04%
#       3280 iter, 1 epoch / 2 epochs
#     3.5693 iters/sec. Estimated time to finish: 0:00:04.471645.
#      total [#################################################.] 99.82%
# this epoch [#################################################.] 99.64%
#       3290 iter, 1 epoch / 2 epochs
#     3.5386 iters/sec. Estimated time to finish: 0:00:01.684505.

# %%
print('test')
eval_rnn.reset_state()
evaluator = extensions.Evaluator(test_iter, eval_model, device=device)
result = evaluator()
print('test perplexity: {}'.format(np.exp(float(result['main/loss']))))
# Out:
# test
# test perplexity: 29889.9857364

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ### Task 2: Sentiment Analysis
#
# 1. **Data Preparation**:
#    - A labeled dataset for sentiment analysis is selected, containing text samples and their corresponding sentiment labels (positive, negative, neutral).
#    - The dataset is preprocessed to tokenize the text and create embeddings.
#
# 2. **Model Definition**:
#    - An LSTM model (`LSTMForSentiment`) is defined to capture long-term dependencies in the text.
#    - Similar to the RNN model, this model is wrapped in a classifier.
#
# 3. **Optimizer Setup**:
#    - The same or a different optimizer (e.g., Adam) is set up for the LSTM model.
#
# 4. **Training Loop**:
#    - A new updater for the LSTM model is created.
#    - A `Trainer` is again established for managing the training process.
#    - The model is evaluated using the `Evaluator` extension, monitoring the accuracy of sentiment classification.
#
# 5. **Logging and Monitoring**:
#    - The training process includes logging metrics such as accuracy and loss at specified intervals.

# %%
import locale
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
# Out:
# 'en_US.UTF-8'

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# Install necessary packages
# !pip install torch
# !pip install keras
# !pip install torchmetrics
# !pip install scikit-learn
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Collecting torchmetrics
#   Downloading torchmetrics-1.4.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.4.1+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.7-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (71.0.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.16.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->torchmetrics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->torchmetrics) (1.3.0)
# Downloading torchmetrics-1.4.2-py3-none-any.whl (869 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.2/869.2 kB 13.0 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.7-py3-none-any.whl (26 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.11.7 torchmetrics-1.4.2
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score, accuracy_score

# %%
reviews_df = pd.read_csv('review.json')

# %%
# Apply the function to the 'overall' column
reviews_df['sentiment'] = reviews_df['overall'].apply(convert_rating_to_sentiment)

# Preprocess the reviews for model training
clean_reviews = reviews_df['reviewText'].tolist()  # Assuming this is the column for text reviews

# Tokenization
tokenizer = Tokenizer(num_words=VOCAB_SIZE)
tokenizer.fit_on_texts(clean_reviews)

# Convert tokens to sequences
sequences = tokenizer.texts_to_sequences(clean_reviews)

# Padding sequences
X = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)

# Converting labels to numerical format
le = LabelEncoder()
y = le.fit_transform(reviews_df['sentiment'])
y = y.reshape(-1, 1)  # Reshape to match the model output

# Convert to PyTorch tensors
inputs_tensor = torch.tensor(X, dtype=torch.long)
outputs_tensor = torch.tensor(y, dtype=torch.float)

# %%
VOCAB_SIZE = 1000
MAX_SEQUENCE_LENGTH = 50
EMBEDDING_DIM = 128
HIDDEN_DIM = 128

# %%
def evaluate_model(model, inputs, outputs):
    model.eval()
    with torch.no_grad():
        predictions = model(inputs)
        predicted_labels = (predictions.squeeze() > 0.5).float()  # Binarize predictions
        accuracy = accuracy_score(outputs.numpy(), predicted_labels.numpy())
        f1 = f1_score(outputs.numpy(), predicted_labels.numpy())

    print(f"Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}")

# Generate random input data for demonstration
inputs = torch.randint(0, VOCAB_SIZE, (100, MAX_SEQUENCE_LENGTH))  # Example input shape
outputs = torch.randint(0, 2, (100, 1)).float()  # Example output shape for binary classification

# %%
# Define RNN model
class RNN(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super(RNN, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_dim)
        self.fc = nn.Linear(hidden_dim, 1)  # Output layer for binary classification

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.rnn(x)
        x = self.fc(x[:, -1, :])  # Only take the last time step
        return torch.sigmoid(x)

# Define LSTM model
class LSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super(LSTM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)
        self.fc = nn.Linear(hidden_dim, 1)  # Output layer for binary classification

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc(x[:, -1, :])  # Only take the last time step
        return torch.sigmoid(x)

# Train RNN
print("Training RNN model:")
rnn_model = RNN(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM)
train_model(rnn_model, inputs, outputs)

# Evaluate RNN
evaluate_model(rnn_model, inputs, outputs)

# Train LSTM
print("Training LSTM model:")
lstm_model = LSTM(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM)
train_model(lstm_model, inputs, outputs)

# Evaluate LSTM
evaluate_model(lstm_model, inputs, outputs)



# Train models with the actual review data
print("Training RNN model with review data:")
train_model(rnn_model, inputs_tensor, outputs_tensor)

# Evaluate RNN on review data
evaluate_model(rnn_model, inputs_tensor, outputs_tensor)

print("Training LSTM model with review data:")
train_model(lstm_model, inputs_tensor, outputs_tensor)

# Evaluate LSTM on review data
evaluate_model(lstm_model, inputs_tensor, outputs_tensor)
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Training RNN model:
# Epoch 1/5, Loss: 0.7000
# Epoch 2/5, Loss: 0.6560
# Epoch 3/5, Loss: 0.6146
# Epoch 4/5, Loss: 0.5751
# Epoch 5/5, Loss: 0.5369
# Training LSTM model:
# Epoch 1/5, Loss: 0.6969
# Epoch 2/5, Loss: 0.6816
# Epoch 3/5, Loss: 0.6668
# Epoch 4/5, Loss: 0.6522
# Epoch 5/5, Loss: 0.6378

# %%
# Evaluate RNN
rnn_accuracy, rnn_f1 = evaluate_model(rnn_model, inputs, outputs)
print(f"RNN Accuracy: {rnn_accuracy:.4f}, F1 Score: {rnn_f1:.4f}")

# Evaluate LSTM
lstm_accuracy, lstm_f1 = evaluate_model(lstm_model, inputs, outputs)
print(f"LSTM Accuracy: {lstm_accuracy:.4f}, F1 Score: {lstm_f1:.4f}")
# Out:
# RNN Accuracy: 9.998, F1 Score: 9.998
# LSTM Accuracy: 0.8400, F1 Score: 0.8571
